# %%
# %run C4_5_6_FULL.py
# Out:
# 4.2.1 Phân bố:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64
# Outcome
# 0    65.1
# 1    34.9
# Name: count, dtype: float64
#
# 4.2.2 So sánh phân phối các chỉ số giữa 2 nhóm
# C:\VScode\CSTTNT25\CSTTNT25\DA_CSTTNT\C4_5_6_FULL.py:134: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[0].set_title("Huyết áp tăng tuyến tính với tuổi")
# Số lượng theo nhóm tuổi:
# Outcome     0   1
# AgeGroup
# 21-30     327  90
# 31-40      81  76
# 41-50      49  64
# >50        43  38
#
# Tỷ lệ mắc bệnh theo nhóm tuổi (%):
# Outcome       0      1
# AgeGroup
# 21-30     78.42  21.58
# 31-40     51.59  48.41
# 41-50     43.36  56.64
# >50       53.09  46.91
# Outcome         0    1  Total  % mắc
# GlucoseGroup
# Diabetes      121  176    297   59.3
# Normal        181   16    197    8.1
# Prediabetes   198   76    274   27.7
# ...
