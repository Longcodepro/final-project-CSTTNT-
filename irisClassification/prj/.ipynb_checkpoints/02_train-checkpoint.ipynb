# %% [markdown]
# # 🤖 Train Model - Bài toán Phân lớp Hoa Iris
# **Môn:** Trí Tuệ Nhân Tạo
# **Bài:** 7 - Bài toán phân lớp
# **Dataset:** iris.csv

# %% [markdown]
# ## Bước 5: Khởi tạo thí nghiệm

# %%
# ── Khai báo thư viện ───────────────────────────────────
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
import os
import pickle
import warnings
from datetime import datetime
warnings.filterwarnings('ignore')

from sklearn.model_selection import KFold, cross_val_score, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.metrics import (
    accuracy_score, classification_report,
    confusion_matrix, ConfusionMatrixDisplay
)
from sklearn.preprocessing import LabelEncoder

# ── Tham số thực nghiệm ─────────────────────────────────
BASE_DIR  = os.path.abspath(os.path.join(os.getcwd(), '..')) \
            if os.path.basename(os.getcwd()) == 'prj' \
            else os.getcwd()

EXP_DIR   = os.path.join(BASE_DIR, 'exps_')
MODEL_DIR = os.path.join(BASE_DIR, 'model')
TRAIN_LOG      = os.path.join(EXP_DIR, 'train_log.xlsx')
N_SPLITS       = 10       # k-fold
RANDOM_STATE   = 42
SCORING        = 'accuracy'

# File dữ liệu từ EDA
FILES = {
    'raw':      (os.path.join(EXP_DIR, 'train_raw.csv'),      os.path.join(EXP_DIR, 'test_raw.csv')),
    'minmax':   (os.path.join(EXP_DIR, 'train_minmax.csv'),   os.path.join(EXP_DIR, 'test_minmax.csv')),
    'standard': (os.path.join(EXP_DIR, 'train_standard.csv'), os.path.join(EXP_DIR, 'test_standard.csv')),
}

os.makedirs(MODEL_DIR, exist_ok=True)
sns.set_theme(style='whitegrid')
plt.rcParams['figure.dpi'] = 100

print('✅ Khai báo thư viện và tham số xong!')
print(f'   Thời gian      : {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}')
print(f'   K-Fold         : {N_SPLITS} folds')
print(f'   Scoring        : {SCORING}')
# Out:
# ✅ Khai báo thư viện và tham số xong!
#    Thời gian      : 2026-03-08 11:48:16
#    K-Fold         : 10 folds
#    Scoring        : accuracy

# %% [markdown]
# ## Bước 6: Dữ liệu kiểm nghiệm

# %%
# Load dữ liệu từ EDA (đã chia 7/3)
def load_data(train_path, test_path):
    train = pd.read_csv(train_path)
    test  = pd.read_csv(test_path)
    X_train = train.iloc[:, :-1].values
    y_train = train.iloc[:, -1].values
    X_test  = test.iloc[:, :-1].values
    y_test  = test.iloc[:, -1].values
    return X_train, X_test, y_train, y_test

# Kiểm tra dữ liệu
for scaler_name, (train_path, test_path) in FILES.items():
    X_tr, X_te, y_tr, y_te = load_data(train_path, test_path)
    print(f'[{scaler_name:8s}] Train: {X_tr.shape} | Test: {X_te.shape}')

print('\n✅ Dữ liệu kiểm nghiệm sẵn sàng!')
print(f'   Chiến lược hold-out : Train 70% / Test 30%')
print(f'   Chiến lược k-fold   : {N_SPLITS}-fold trên tập Train')
# Out:
# [raw     ] Train: (105, 4) | Test: (45, 4)
# [minmax  ] Train: (105, 4) | Test: (45, 4)
# [standard] Train: (105, 4) | Test: (45, 4)
#
# ✅ Dữ liệu kiểm nghiệm sẵn sàng!
#    Chiến lược hold-out : Train 70% / Test 30%
#    Chiến lược k-fold   : 10-fold trên tập Train

# %% [markdown]
# ## Bước 7: Lượng giá thuật toán
# ### 7.1 Baselines - 6 model tham số mặc định

# %%
def get_baseline_models():
    return [
        ('Logistic Regression',   LogisticRegression(max_iter=200, random_state=RANDOM_STATE)),
        ('Linear Discriminant',   LinearDiscriminantAnalysis()),
        ('K-Neighbors',           KNeighborsClassifier()),
        ('Decision Tree',         DecisionTreeClassifier(random_state=RANDOM_STATE)),
        ('Gaussian Naive Bayes',  GaussianNB()),
        ('SVM',                   SVC(random_state=RANDOM_STATE)),
    ]

kfold = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)
baseline_results = []

for scaler_name, (train_path, test_path) in FILES.items():
    X_train, _, y_train, _ = load_data(train_path, test_path)
    print(f'\n📊 [{scaler_name.upper()}] Baseline - {N_SPLITS}-Fold Cross Validation:')
    print(f'  {"Model":<25} {"Mean Acc":>10} {"Std":>8}')
    print('  ' + '-' * 45)
    for name, model in get_baseline_models():
        scores = cross_val_score(model, X_train, y_train, cv=kfold, scoring=SCORING)
        baseline_results.append({
            'Scaler':   scaler_name,
            'Model':    name,
            'Loại':     'Baseline',
            'Mean Acc': round(scores.mean(), 4),
            'Std Acc':  round(scores.std(), 4),
            'Min Acc':  round(scores.min(), 4),
            'Max Acc':  round(scores.max(), 4),
            'Params':   'default',
        })
        print(f'  {name:<25} {scores.mean():>10.4f} {scores.std():>8.4f}')

df_baseline = pd.DataFrame(baseline_results)
print('\n✅ Baseline xong!')
# Out:
# 📊 [RAW] Baseline - 10-Fold Cross Validation:
#   Model                       Mean Acc      Std
#   ---------------------------------------------
#   Logistic Regression           0.9718   0.0431
#   Linear Discriminant           0.9718   0.0431
#   K-Neighbors                   0.9718   0.0431
#   Decision Tree                 0.9427   0.0469
#   Gaussian Naive Bayes          0.9727   0.0417
#   SVM                           0.9718   0.0431
#
# 📊 [MINMAX] Baseline - 10-Fold Cross Validation:
#   Model                       Mean Acc      Std
#   ---------------------------------------------
#   Logistic Regression           0.9436   0.0615
#   Linear Discriminant           0.9718   0.0431
#   K-Neighbors                   0.9718   0.0431
#   Decision Tree                 0.9427   0.0469
#   Gaussian Naive Bayes          0.9727   0.0417
#   SVM                           0.9718   0.0431
#
# 📊 [STANDARD] Baseline - 10-Fold Cross Validation:
#   Model                       Mean Acc      Std
#   ---------------------------------------------
#   Logistic Regression           0.9718   0.0431
#   Linear Discriminant           0.9718   0.0431
#   K-Neighbors                   0.9618   0.0469
#   Decision Tree                 0.9427   0.0469
#   Gaussian Naive Bayes          0.9727   0.0417
#   SVM                           0.9718   0.0431
#
# ✅ Baseline xong!

# %%
# Biểu đồ Baseline
fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True)
colors_bar = ['#4C72B0','#DD8452','#55A868','#C44E52','#8172B2','#937860']

for idx, scaler_name in enumerate(['raw', 'minmax', 'standard']):
    subset = df_baseline[df_baseline['Scaler'] == scaler_name]
    bars = axes[idx].barh(subset['Model'], subset['Mean Acc'],
                          xerr=subset['Std Acc'], color=colors_bar,
                          edgecolor='white', capsize=4)
    axes[idx].set_title(f'Baseline [{scaler_name.upper()}]', fontweight='bold', fontsize=12)
    axes[idx].set_xlabel('Mean Accuracy')
    axes[idx].set_xlim(0.5, 1.05)
    for bar, row in zip(bars, subset.itertuples()):
        axes[idx].text(row._4 + 0.005, bar.get_y() + bar.get_height()/2,
                       f'{row._4:.4f}', va='center', fontsize=9, fontweight='bold')

plt.suptitle('Baseline Models - K-Fold Accuracy (Mean ± Std)', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig(os.path.join(EXP_DIR, 'plot_baseline.png'), bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 7.2 Tinh chỉnh tham số - KNN & SVM

# %%
# Tham số tinh chỉnh
KNN_PARAMS = {'n_neighbors': [1, 3, 5, 7, 9, 11, 13, 15]}
SVM_PARAMS = {'C': [0.01, 0.1, 1, 10, 100], 'kernel': ['linear', 'rbf', 'poly']}

tuned_results  = []
best_estimators = {}  # lưu model tốt nhất mỗi scaler

for scaler_name, (train_path, test_path) in FILES.items():
    X_train, _, y_train, _ = load_data(train_path, test_path)
    print(f'\n🔧 [{scaler_name.upper()}] Tinh chỉnh tham số:')

    # KNN
    knn_grid = GridSearchCV(KNeighborsClassifier(), KNN_PARAMS,
                             cv=kfold, scoring=SCORING)
    knn_grid.fit(X_train, y_train)
    tuned_results.append({
        'Scaler':   scaler_name,
        'Model':    'K-Neighbors (tuned)',
        'Loại':     'Tuned',
        'Mean Acc': round(knn_grid.best_score_, 4),
        'Std Acc':  0,
        'Min Acc':  0,
        'Max Acc':  0,
        'Params':   str(knn_grid.best_params_),
    })
    print(f'  KNN best   : {knn_grid.best_score_:.4f} | Params: {knn_grid.best_params_}')

    # SVM
    svm_grid = GridSearchCV(SVC(random_state=RANDOM_STATE), SVM_PARAMS,
                             cv=kfold, scoring=SCORING)
    svm_grid.fit(X_train, y_train)
    tuned_results.append({
        'Scaler':   scaler_name,
        'Model':    'SVM (tuned)',
        'Loại':     'Tuned',
        'Mean Acc': round(svm_grid.best_score_, 4),
        'Std Acc':  0,
        'Min Acc':  0,
        'Max Acc':  0,
        'Params':   str(svm_grid.best_params_),
    })
    print(f'  SVM best   : {svm_grid.best_score_:.4f} | Params: {svm_grid.best_params_}')

    best_estimators[scaler_name] = {
        'knn_tuned': knn_grid.best_estimator_,
        'svm_tuned': svm_grid.best_estimator_,
    }

df_tuned = pd.DataFrame(tuned_results)
print('\n✅ Tinh chỉnh xong!')
# Out:
# 🔧 [RAW] Tinh chỉnh tham số:
#   KNN best   : 0.9718 | Params: {'n_neighbors': 1}
#   SVM best   : 0.9809 | Params: {'C': 100, 'kernel': 'linear'}
#
# 🔧 [MINMAX] Tinh chỉnh tham số:
#   KNN best   : 0.9718 | Params: {'n_neighbors': 3}
#   SVM best   : 0.9818 | Params: {'C': 1, 'kernel': 'linear'}
#
# 🔧 [STANDARD] Tinh chỉnh tham số:
#   KNN best   : 0.9718 | Params: {'n_neighbors': 9}
#   SVM best   : 0.9818 | Params: {'C': 0.1, 'kernel': 'linear'}
#
# ✅ Tinh chỉnh xong!

# %%
# So sánh Baseline vs Tuned
df_kfold_all = pd.concat([df_baseline, df_tuned], ignore_index=True)

fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)
palette = {'Baseline': '#4C72B0', 'Tuned': '#DD8452'}

for idx, scaler_name in enumerate(['raw', 'minmax', 'standard']):
    subset = df_kfold_all[df_kfold_all['Scaler'] == scaler_name].copy()
    sns.barplot(data=subset, x='Mean Acc', y='Model', hue='Loại',
                palette=palette, ax=axes[idx], orient='h')
    axes[idx].set_title(f'[{scaler_name.upper()}] Baseline vs Tuned', fontweight='bold')
    axes[idx].set_xlabel('Mean Accuracy')
    axes[idx].set_xlim(0.5, 1.05)
    axes[idx].legend(title='Loại', fontsize=8)

plt.suptitle('So sánh Baseline vs Tuned (K-Fold Accuracy)', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig(os.path.join(EXP_DIR, 'plot_baseline_vs_tuned.png'), bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Bước 8: Kiểm nghiệm kết quả trên Test (Finalize Model)

# %%
test_results = []
best_overall = {'acc': 0, 'model': None, 'name': '', 'scaler': ''}

for scaler_name, (train_path, test_path) in FILES.items():
    X_train, X_test, y_train, y_test = load_data(train_path, test_path)
    print(f'\n🧪 [{scaler_name.upper()}] Kiểm nghiệm trên Test Set:')
    print(f'  {"Model":<25} {"Test Acc":>10}')
    print('  ' + '-' * 37)

    # Baselines trên test
    for name, model in get_baseline_models():
        model.fit(X_train, y_train)
        acc = accuracy_score(y_test, model.predict(X_test))
        test_results.append({
            'Scaler': scaler_name, 'Model': name,
            'Loại': 'Baseline', 'Test Acc': round(acc, 4)
        })
        print(f'  {name:<25} {acc:>10.4f}')
        if acc > best_overall['acc']:
            best_overall = {'acc': acc, 'model': model, 'name': name, 'scaler': scaler_name}

    # Tuned models trên test
    for tune_name, estimator in [
        ('K-Neighbors (tuned)', best_estimators[scaler_name]['knn_tuned']),
        ('SVM (tuned)',         best_estimators[scaler_name]['svm_tuned']),
    ]:
        estimator.fit(X_train, y_train)
        acc = accuracy_score(y_test, estimator.predict(X_test))
        test_results.append({
            'Scaler': scaler_name, 'Model': tune_name,
            'Loại': 'Tuned', 'Test Acc': round(acc, 4)
        })
        print(f'  {tune_name:<25} {acc:>10.4f}')
        if acc > best_overall['acc']:
            best_overall = {'acc': acc, 'model': estimator, 'name': tune_name, 'scaler': scaler_name}

df_test = pd.DataFrame(test_results)
print(f'\n🏆 Best overall: {best_overall["name"]} [{best_overall["scaler"]}] | Acc: {best_overall["acc"]:.4f}')
# Out:
# 🧪 [RAW] Kiểm nghiệm trên Test Set:
#   Model                       Test Acc
#   -------------------------------------
#   Logistic Regression           0.9333
#   Linear Discriminant           0.9778
#   K-Neighbors                   0.9778
#   Decision Tree                 0.9333
#   Gaussian Naive Bayes          0.9111
#   SVM                           0.9556
#   K-Neighbors (tuned)           0.9333
#   SVM (tuned)                   0.9111
#
# 🧪 [MINMAX] Kiểm nghiệm trên Test Set:
#   Model                       Test Acc
#   -------------------------------------
#   Logistic Regression           0.8667
#   Linear Discriminant           0.9778
#   K-Neighbors                   0.9333
#   Decision Tree                 0.9333
#   Gaussian Naive Bayes          0.9111
#   SVM                           0.9333
#   K-Neighbors (tuned)           0.9333
#   SVM (tuned)                   0.9111
#
# 🧪 [STANDARD] Kiểm nghiệm trên Test Set:
#   Model                       Test Acc
#   -------------------------------------
#   Logistic Regression           0.9111
#   Linear Discriminant           0.9778
#   K-Neighbors                   0.9111
#   Decision Tree                 0.9111
#   Gaussian Naive Bayes          0.9111
#   SVM                           0.9333
#   K-Neighbors (tuned)           0.9556
#   SVM (tuned)                   0.9111
#
# 🏆 Best overall: Linear Discriminant [raw] | Acc: 0.9778

# %%
# Biểu đồ Test Accuracy
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)
palette2 = {'Baseline': '#55A868', 'Tuned': '#C44E52'}

for idx, scaler_name in enumerate(['raw', 'minmax', 'standard']):
    subset = df_test[df_test['Scaler'] == scaler_name]
    sns.barplot(data=subset, x='Test Acc', y='Model', hue='Loại',
                palette=palette2, ax=axes[idx], orient='h')
    axes[idx].set_title(f'[{scaler_name.upper()}] Test Accuracy', fontweight='bold')
    axes[idx].set_xlabel('Test Accuracy')
    axes[idx].set_xlim(0.5, 1.05)
    axes[idx].axvline(x=1.0, color='gray', linestyle='--', alpha=0.5)
    axes[idx].legend(title='Loại', fontsize=8)

plt.suptitle('Test Set Accuracy - Tất cả Model & Scaler', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig(os.path.join(EXP_DIR, 'plot_test_accuracy.png'), bbox_inches='tight')
plt.show()

# %%
# Confusion Matrix của model tốt nhất
best_model  = best_overall['model']
best_scaler = best_overall['scaler']
X_train, X_test, y_train, y_test = load_data(*FILES[best_scaler])
best_model.fit(X_train, y_train)
y_pred = best_model.predict(X_test)
classes = np.unique(y_test)

fig, ax = plt.subplots(figsize=(7, 5))
cm = confusion_matrix(y_test, y_pred, labels=classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(ax=ax, colorbar=True, cmap='Blues')
ax.set_title(f'Confusion Matrix\n{best_overall["name"]} [{best_scaler}] | Acc: {best_overall["acc"]:.4f}',
             fontweight='bold')
plt.tight_layout()
plt.savefig(os.path.join(EXP_DIR, 'plot_confusion_matrix.png'), bbox_inches='tight')
plt.show()

print('\n=== Classification Report ===')
print(classification_report(y_test, y_pred, target_names=classes))
# Out:
# === Classification Report ===
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        15
# Iris-versicolor       0.94      1.00      0.97        15
#  Iris-virginica       1.00      0.93      0.97        15
#
#        accuracy                           0.98        45
#       macro avg       0.98      0.98      0.98        45
#    weighted avg       0.98      0.98      0.98        45

# %%
# So sánh tổng hợp K-Fold vs Test
df_kfold_compare = df_kfold_all[['Scaler','Model','Mean Acc']].rename(columns={'Mean Acc':'Accuracy'})
df_kfold_compare['Phase'] = 'K-Fold (Train)'
df_test_compare  = df_test[['Scaler','Model','Test Acc']].rename(columns={'Test Acc':'Accuracy'})
df_test_compare['Phase'] = 'Test'
df_compare = pd.concat([df_kfold_compare, df_test_compare], ignore_index=True)

fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)
for idx, scaler_name in enumerate(['raw', 'minmax', 'standard']):
    subset = df_compare[df_compare['Scaler'] == scaler_name]
    sns.barplot(data=subset, x='Accuracy', y='Model', hue='Phase',
                palette={'K-Fold (Train)': '#4C72B0', 'Test': '#DD8452'},
                ax=axes[idx], orient='h')
    axes[idx].set_title(f'[{scaler_name.upper()}] K-Fold vs Test', fontweight='bold')
    axes[idx].set_xlim(0.5, 1.05)
    axes[idx].legend(fontsize=8)

plt.suptitle('So sánh K-Fold Accuracy vs Test Accuracy', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig(os.path.join(EXP_DIR, 'plot_kfold_vs_test.png'), bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Lưu kết quả thí nghiệm

# %%
import os
from openpyxl import load_workbook

# ── Lưu model tốt nhất ──────────────────────────────
os.makedirs(MODEL_DIR, exist_ok=True)
model_path = os.path.join(MODEL_DIR, f'best_model_{best_overall["scaler"]}.pkl')
with open(model_path, 'wb') as f:
    pickle.dump(best_overall['model'], f)
print(f'💾 Đã lưu model: {model_path}')

# ── Tạo df_exp_info ──────────────────────────────────
df_exp_info = pd.DataFrame([{
    'Thời gian':     datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
    'Dataset':       'iris.csv',
    'K-Fold':        N_SPLITS,
    'Test size':     '30%',
    'Best model':    best_overall['name'],
    'Best scaler':   best_overall['scaler'],
    'Best Test Acc': best_overall['acc'],
    'Model file':    model_path,
}])

# ── Ghi Excel ────────────────────────────────────────
file_exists = os.path.exists(TRAIN_LOG)

if not file_exists:
    with pd.ExcelWriter(TRAIN_LOG, engine='openpyxl', mode='w') as writer:
        df_exp_info.to_excel(writer,   sheet_name='Thong_tin_TN',    index=False)
        df_baseline.to_excel(writer,   sheet_name='Baseline_KFold',  index=False)
        df_tuned.to_excel(writer,      sheet_name='Tuned_KFold',     index=False)
        df_test.to_excel(writer,       sheet_name='Test_Results',    index=False)
        df_kfold_all.to_excel(writer,  sheet_name='Tat_ca_KFold',    index=False)
    print(f'🆕 Tạo file mới: {TRAIN_LOG}')
else:
    df_old     = pd.read_excel(TRAIN_LOG, sheet_name='Thong_tin_TN')
    df_history = pd.concat([df_old, df_exp_info], ignore_index=True)
    with pd.ExcelWriter(TRAIN_LOG, engine='openpyxl', mode='a',
                        if_sheet_exists='replace') as writer:
        df_history.to_excel(writer,    sheet_name='Thong_tin_TN',    index=False)
        df_baseline.to_excel(writer,   sheet_name='Baseline_KFold',  index=False)
        df_tuned.to_excel(writer,      sheet_name='Tuned_KFold',     index=False)
        df_test.to_excel(writer,       sheet_name='Test_Results',    index=False)
        df_kfold_all.to_excel(writer,  sheet_name='Tat_ca_KFold',    index=False)
    print(f'➕ Đã thêm lịch sử vào: {TRAIN_LOG}')

print(f'✅ Sheet Thong_tin_TN: lưu tất cả lịch sử theo dòng')
print(f'✅ Các sheet khác: lưu kết quả mới nhất')
# Out:
# 💾 Đã lưu model: ../model\best_model_raw.pkl
# ✅ Đã ghi kết quả vào: ../exps_\train_log.xlsx

# %% [markdown]
# ## Tổng kết thực nghiệm

# %%
print('=' * 60)
print('TỔNG KẾT THỰC NGHIỆM - IRIS CLASSIFICATION')
print('=' * 60)
print(f'\n📌 Cấu hình thực nghiệm:')
print(f'   K-Fold     : {N_SPLITS} folds')
print(f'   Scoring    : {SCORING}')
print(f'   Scalers    : raw, minmax, standard')
print(f'\n📌 Số model đã train:')
print(f'   Baseline   : 6 models x 3 scalers = 18')
print(f'   Tuned      : 2 models x 3 scalers = 6')
print(f'   Tổng cộng  : 24 models')
print(f'\n🏆 Model tốt nhất:')
print(f'   Tên        : {best_overall["name"]}')
print(f'   Scaler     : {best_overall["scaler"]}')
print(f'   Test Acc   : {best_overall["acc"]:.4f}')
print(f'   Lưu tại    : {model_path}')
print(f'\n📁 File kết quả:')
print(f'   {TRAIN_LOG}')
print('=' * 60)
# Out:
# ============================================================
# TỔNG KẾT THỰC NGHIỆM - IRIS CLASSIFICATION
# ============================================================
#
# 📌 Cấu hình thực nghiệm:
#    K-Fold     : 10 folds
#    Scoring    : accuracy
#    Scalers    : raw, minmax, standard
#
# 📌 Số model đã train:
#    Baseline   : 6 models x 3 scalers = 18
#    Tuned      : 2 models x 3 scalers = 6
#    Tổng cộng  : 24 models
#
# 🏆 Model tốt nhất:
#    Tên        : Linear Discriminant
#    Scaler     : raw
#    Test Acc   : 0.9778
#    Lưu tại    : ../model\best_model_raw.pkl
#
# 📁 File kết quả:
#    ../exps_\train_log.xlsx
# ============================================================
